# %% [markdown]
# # Data Cleaning
#    - Missing Data
#      - Delete the records
#      - Fill missing data
#    - Duplicate Records
#      - Delete duplicates

# %%
import pandas as pd

# %%
data = pd.read_excel("employee.xlsx")

# %%
data.shape
# Out:
# (18, 6)

# %%
data.head()
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0
# 2       3    1203     Officer         HR  28.0       NaN
# 3       4    1005     Manager         HR  45.0  120000.0
# 4       5    2123  Office Boy   Accounts  27.0   45000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Serial       18 non-null     int64
#  1   Emp_ID       18 non-null     int64
#  2   Designation  18 non-null     object
#  3   Department   16 non-null     object
#  4   Age          17 non-null     float64
#  5   Salary       15 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 996.0+ bytes

# %%
data.isna().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.notna().sum()
# Out:
# Serial         18
# Emp_ID         18
# Designation    18
# Department     16
# Age            17
# Salary         15
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Serial         18
# Emp_ID         18
# Designation    18
# Department     16
# Age            17
# Salary         15
# dtype: int64

# %%
data.Department.isna().sum()
# Out:
# 2

# %%
data.Department.dtype
# Out:
# dtype('O')

# %%
data.fillna("Missing Data")
# Out:
#     Serial  Emp_ID Designation    Department           Age        Salary
# 0        1    1101     Manager      Accounts          50.0      200000.0
# 1        2    1107     Officer            IT          30.0       80000.0
# 2        3    1203     Officer            HR          28.0  Missing Data
# 3        4    1005     Manager            HR          45.0      120000.0
# 4        5    2123  Office Boy      Accounts          27.0       45000.0
# 5        6    2451  Accountant  Missing Data          34.0      100000.0
# 6        7    1111  Accountant      Accounts  Missing Data      110000.0
# 7        8    1001     Officer            IT          25.0       75000.0
# 8        9    1234     Manager            IT          23.0  Missing Data
# 9       10    2156    Engineer    Production          45.0       89000.0
# 10      11    6543     Officer    Production          29.0      100000.0
# 11      12    3214  Accountant       Account          49.0      123000.0
# ...

# %%
data.fillna(0)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       0.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant           0  34.0  100000.0
# 6        7    1111  Accountant    Accounts   0.0  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       0.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.Department.mode()[0]
# Out:
# 'IT'

# %%
data.Department.value_counts()
# Out:
# Department
# IT            5
# Accounts      4
# Production    4
# HR            2
# Account       1
# Name: count, dtype: int64

# %%
data.Department.fillna(data.Department.mode()[0],inplace=True)

# %%
import seaborn as sns
sns.boxplot(data.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
data.Age.fillna(data.Age.median(),inplace=True)

# %%
sns.boxplot(data.Salary)
# Out:
# <Axes: ylabel='Salary'>

# %%
data.Salary.fillna(data.Salary.median(),inplace=True)

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0   90000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant          IT  34.0  100000.0
# 6        7    1111  Accountant    Accounts  30.0  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0   90000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data = pd.read_excel("employee.xlsx")

# %%
data.dropna(axis=0)
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.dropna(axis=1)
# Out:
#     Serial  Emp_ID Designation
# 0        1    1101     Manager
# 1        2    1107     Officer
# 2        3    1203     Officer
# 3        4    1005     Manager
# 4        5    2123  Office Boy
# 5        6    2451  Accountant
# 6        7    1111  Accountant
# 7        8    1001     Officer
# 8        9    1234     Manager
# 9       10    2156    Engineer
# 10      11    6543     Officer
# 11      12    3214  Accountant
# 12      13    2156    Engineer
# 13      14    1098     Officer
# 14      15    2912     Officer
# 15      16    1222     Officer
# 16      17    2156    Engineer
# 17      18    2123  Office Boy

# %%
data.dropna(how="all")
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(how='any')
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.dropna(thresh=16,axis=1)
# Out:
#     Serial  Emp_ID Designation  Department   Age
# 0        1    1101     Manager    Accounts  50.0
# 1        2    1107     Officer          IT  30.0
# 2        3    1203     Officer          HR  28.0
# 3        4    1005     Manager          HR  45.0
# 4        5    2123  Office Boy    Accounts  27.0
# 5        6    2451  Accountant         NaN  34.0
# 6        7    1111  Accountant    Accounts   NaN
# 7        8    1001     Officer          IT  25.0
# 8        9    1234     Manager          IT  23.0
# 9       10    2156    Engineer  Production  45.0
# 10      11    6543     Officer  Production  29.0
# 11      12    3214  Accountant     Account  49.0
# 12      13    2156    Engineer  Production  45.0
# 13      14    1098     Officer          IT  25.0
# 14      15    2912     Officer          IT  31.0
# 15      16    1222     Officer         NaN  25.0
# 16      17    2156    Engineer  Production  45.0
# 17      18    2123  Office Boy    Accounts  27.0

# %%
data.dropna(thresh=int(data.shape[0]*.95), axis=1)
# Out:
#     Serial  Emp_ID Designation   Age
# 0        1    1101     Manager  50.0
# 1        2    1107     Officer  30.0
# 2        3    1203     Officer  28.0
# 3        4    1005     Manager  45.0
# 4        5    2123  Office Boy  27.0
# 5        6    2451  Accountant  34.0
# 6        7    1111  Accountant   NaN
# 7        8    1001     Officer  25.0
# 8        9    1234     Manager  23.0
# 9       10    2156    Engineer  45.0
# 10      11    6543     Officer  29.0
# 11      12    3214  Accountant  49.0
# 12      13    2156    Engineer  45.0
# 13      14    1098     Officer  25.0
# 14      15    2912     Officer  31.0
# 15      16    1222     Officer  25.0
# 16      17    2156    Engineer  45.0
# 17      18    2123  Office Boy  27.0

# %%
data.dropna(how="any", subset=['Emp_ID', 'Salary'])
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.fillna({'Emp_ID':data.Emp_ID.mode()[0],
             "Designation":data.Designation.mode()[0],
             "Department":data.Department.mode()[0],
             "Age":data.Age.median(),
             "Salary":data.Salary.median()},inplace=True)

# %% [markdown]
# # Duplicates

# %%
data.set_index("Serial", inplace=True)

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0   90000.0
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant          IT  34.0  100000.0
# 7         1111  Accountant    Accounts  30.0  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0   90000.0
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer          IT  25.0   90000.0
# ...

# %%
data.duplicated().sum()
# Out:
# 3

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated(subset=['Designation',"Department"])]
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 8         1001     Officer          IT  25.0   75000.0
# 13        2156    Engineer  Production  45.0   89000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 17        2156    Engineer  Production  45.0   89000.0
# 18        2123  Office Boy    Accounts  27.0   45000.0

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0       NaN
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant         NaN  34.0  100000.0
# 7         1111  Accountant    Accounts   NaN  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0       NaN
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer         NaN  25.0       NaN

# %%
data
# Out:
#         Emp_ID Designation  Department   Age    Salary
# Serial
# 1         1101     Manager    Accounts  50.0  200000.0
# 2         1107     Officer          IT  30.0   80000.0
# 3         1203     Officer          HR  28.0   90000.0
# 4         1005     Manager          HR  45.0  120000.0
# 5         2123  Office Boy    Accounts  27.0   45000.0
# 6         2451  Accountant          IT  34.0  100000.0
# 7         1111  Accountant    Accounts  30.0  110000.0
# 8         1001     Officer          IT  25.0   75000.0
# 9         1234     Manager          IT  23.0   90000.0
# 10        2156    Engineer  Production  45.0   89000.0
# 11        6543     Officer  Production  29.0  100000.0
# 12        3214  Accountant     Account  49.0  123000.0
# 14        1098     Officer          IT  25.0  100000.0
# 15        2912     Officer          IT  31.0   90000.0
# 16        1222     Officer          IT  25.0   90000.0

# %%
data.to_excel("Employee_cleaned.xlsx")

# %%
data = pd.read_csv("car_data.csv")

# %%
data.shape
# Out:
# (892, 6)

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data.name
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 2                  Maruti Suzuki Alto 800 Vxi
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
#                         ...
# 887                                        Ta
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# 890                  Honda Amaze 1.2 E i VTEC
# 891                 Chevrolet Sail 1.2 LT ABS
# Name: name, Length: 892, dtype: object

# %%
data.name[:3]
# galat
# Out:
# 0    Hyundai Santro Xing XO eRLX Euro III
# 1                 Mahindra Jeep CL550 MDI
# 2              Maruti Suzuki Alto 800 Vxi
# Name: name, dtype: object

# %%
data.name.str[:3]
# galat
# Out:
# 0      Hyu
# 1      Mah
# 2      Mar
# 3      Hyu
# 4      For
#       ...
# 887     Ta
# 888    Tat
# 889    Mah
# 890    Hon
# 891    Che
# Name: name, Length: 892, dtype: object

# %%
data.name = data.name.str.split().str[:3].str.join(" ")

# %%
data.company.isna().sum()
# Out:
# 0

# %%
data.year.value_counts()
# Out:
# year
# 2015    117
# 2014     94
# 2013     94
# 2016     76
# 2012     75
#        ...
# ture      1
# emi       1
# able      1
# no.       1
# zest      1
# Name: count, Length: 61, dtype: int64

# %%
data1 = data[data.year.str.isnumeric()]

# %%
data1.year = data1.year.astype(int)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data1.Price.value_counts()
# Out:
# Price
# Ask For Price    23
# 2,50,000         16
# 3,50,000         12
# 4,00,000         11
# 1,80,000         11
#                  ..
# 7,49,999          1
# 11,30,000         1
# 10,74,999         1
# 3,24,999          1
# 5,00,001          1
# Name: count, Length: 273, dtype: int64

# %%
data1.Price.replace("Ask For Price", '0',inplace=True)

# %%
data1.Price.value_counts()
# Out:
# Price
# 0            23
# 2,50,000     16
# 3,50,000     12
# 4,00,000     11
# 1,80,000     11
#              ..
# 7,49,999      1
# 11,30,000     1
# 10,74,999     1
# 3,24,999      1
# 5,00,001      1
# Name: count, Length: 273, dtype: int64

# %%
data1.Price=data1.Price.str.replace(",", "").astype(int)

# %%
data1.Price.replace(0,data1.Price.median(),inplace=True)

# %%
data1.kms_driven = data1.kms_driven.replace('Petrol',0, inplace=True)

# %%
data1.kms_driven.str.replace(",","").str.replace("kms", "")
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 886    None
# 888    None
# 889    None
# 890    None
# 891    None
# Name: kms_driven, Length: 842, dtype: object
