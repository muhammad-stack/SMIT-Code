# %%
import pandas as pd

# %%
data = pd.read_csv("imdb-top-1000.csv")

# %%
data
# Out:
#                  Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption           1994      142   Drama          9.3
# 1               The Godfather           1972      175   Crime          9.2
# 2             The Dark Knight           2008      152  Action          9.0
# 3      The Godfather: Part II           1974      202   Crime          9.0
# 4                12 Angry Men           1957       96   Crime          9.0
# ..                        ...            ...      ...     ...          ...
# 995    Breakfast at Tiffany's           1961      115  Comedy          7.6
# 996                     Giant           1956      201   Drama          7.6
# 997     From Here to Eternity           1953      118   Drama          7.6
# 998                  Lifeboat           1944       97   Drama          7.6
# 999              The 39 Steps           1935       86   Crime          7.6
#
# ...

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
data.Released_Year.value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %%
data[data.Released_Year=="PG"]
# Out:
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating    Director  \
# 966    Apollo 13            PG      140  Adventure          7.6  Ron Howard
#
#          Star1  No_of_Votes        Gross  Metascore
# 966  Tom Hanks       269197  173837933.0       77.0

# %%
data.loc[966:966, 'Released_Year'] = 2014

# %%
data.Released_Year.dtype
# Out:
# dtype('O')

# %%
data.Released_Year.value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# 2014     1
# Name: count, Length: 100, dtype: int64

# %%
data.Released_Year = data.Released_Year.astype('int')

# %%
data.Released_Year.dtype
# Out:
# dtype('int32')

# %%
data.head()
# Out:
#                Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption           1994      142   Drama          9.3
# 1             The Godfather           1972      175   Crime          9.2
# 2           The Dark Knight           2008      152  Action          9.0
# 3    The Godfather: Part II           1974      202   Crime          9.0
# 4              12 Angry Men           1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
#All the films release in the year 2008
data[data.Released_Year==2008]
# Out:
#                             Series_Title  Released_Year  Runtime      Genre  \
# 2                        The Dark Knight           2008      152     Action
# 66                                WALL·E           2008       98  Animation
# 224                          A Wednesday           2008      104     Action
# 225                          Gran Torino           2008      116      Drama
# 227                            Okuribito           2008      130      Drama
# 351                              Yip Man           2008      106     Action
# 354                  Slumdog Millionaire           2008      120      Drama
# 487               Låt den rätte komma in           2008      114      Crime
# 489                         The Wrestler           2008      109      Drama
# 494                            In Bruges           2008      107     Comedy
# 502                             Iron Man           2008      126     Action
# ...

# %%
data[(data.Released_Year==2008) & (data.Genre=="Action")]
# Out:
#         Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 2    The Dark Knight           2008      152  Action          9.0
# 224      A Wednesday           2008      104  Action          8.1
# 351          Yip Man           2008      106  Action          8.0
# 502         Iron Man           2008      126  Action          7.9
# 608       Chugyeokja           2008      125  Action          7.8
# 615            Taken           2008       90  Action          7.8
#
#               Director              Star1  No_of_Votes        Gross  Metascore
# 2    Christopher Nolan     Christian Bale      2303232  534858444.0       84.0
# 224      Neeraj Pandey        Anupam Kher        73891  573329738.0        NaN
# 351         Wilson Yip         Donnie Yen       211427  613703997.0       59.0
# 502        Jon Favreau  Robert Downey Jr.       939644  318412101.0       79.0
# 608        Hong-jin Na      Kim Yoon-seok        58468  369366051.0       64.0
# ...

# %%
# Gross amount earned by action movies in the year 2008

data[(data.Released_Year==2008) & (data.Genre=="Action")]['Gross'].sum()
# Out:
# 2554671320.0

# %%
# The most successful movie in the data in terms of Gross amount earned.
data.Gross.max()
# Out:
# 936662225.0

# %%
data[data.Gross==data.Gross.max()]
# Out:
#                                    Series_Title  Released_Year  Runtime  \
# 477  Star Wars: Episode VII - The Force Awakens           2015      138
#
#       Genre  IMDB_Rating     Director         Star1  No_of_Votes        Gross  \
# 477  Action          7.9  J.J. Abrams  Daisy Ridley       860823  936662225.0
#
#      Metascore
# 477       80.0

# %%
data.Runtime.max()
# Out:
# 321

# %%
data[data.Runtime==data.Runtime.max()]
# Out:
#            Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 140  Gangs of Wasseypur           2012      321  Action          8.2
#
#            Director           Star1  No_of_Votes      Gross  Metascore
# 140  Anurag Kashyap  Manoj Bajpayee        82365  5257741.0       89.0

# %%
data.Director.value_counts().tail()
# Out:
# Director
# Neill Blomkamp     1
# Tomas Alfredson    1
# Duncan Jones       1
# Jacques Audiard    1
# George Stevens     1
# Name: count, dtype: int64

# %%
data[data.Genre=='Comedy']['Director'].mode()
# Out:
# 0    Woody Allen
# Name: Director, dtype: object

# %%
data[data.No_of_Votes==data.No_of_Votes.min()]['Star1'].values[0]
# Out:
# 'Leslie Cheung'

# %%
data[data.No_of_Votes == data.No_of_Votes.min()]
# Out:
#        Series_Title  Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 264  Ba wang bie ji           1993      171  Drama          8.1  Kaige Chen
#
#              Star1  No_of_Votes      Gross  Metascore
# 264  Leslie Cheung        25088  5216888.0        NaN

# %%
data[(data.Released_Year==2008) & (data.Genre=='Action')]
# Out:
#         Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 2    The Dark Knight           2008      152  Action          9.0
# 224      A Wednesday           2008      104  Action          8.1
# 351          Yip Man           2008      106  Action          8.0
# 502         Iron Man           2008      126  Action          7.9
# 608       Chugyeokja           2008      125  Action          7.8
# 615            Taken           2008       90  Action          7.8
#
#               Director              Star1  No_of_Votes        Gross  Metascore
# 2    Christopher Nolan     Christian Bale      2303232  534858444.0       84.0
# 224      Neeraj Pandey        Anupam Kher        73891  573329738.0        NaN
# 351         Wilson Yip         Donnie Yen       211427  613703997.0       59.0
# 502        Jon Favreau  Robert Downey Jr.       939644  318412101.0       79.0
# 608        Hong-jin Na      Kim Yoon-seok        58468  369366051.0       64.0
# ...

# %%
data[data.Genre=="Drama"]['IMDB_Rating'].mean()
# Out:
# 7.957439446366782

# %%
data[data.Genre=="Action"]['IMDB_Rating'].mean()
# Out:
# 7.9494186046511635

# %%
data[data.Genre=="Comedy"]['IMDB_Rating'].mean()
# Out:
# 7.901290322580647

# %%
data[data.Genre=="Crime"]['IMDB_Rating'].mean()
# Out:
# 8.016822429906542

# %%
data[data.Genre=="Animation"]['IMDB_Rating'].mean()
# Out:
# 7.930487804878048

# %%
data[data.Genre=="Adventure"]['IMDB_Rating'].mean()
# Out:
# 7.9375

# %%
data.Genre.unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %% [markdown]
# # GroupBy

# %%
data.groupby('Genre')['IMDB_Rating'].agg(['mean', 'max', "min"])
# Out:
#                mean  max  min
# Genre
# Action     7.949419  9.0  7.6
# Adventure  7.937500  8.6  7.6
# Animation  7.930488  8.6  7.6
# Biography  7.938636  8.9  7.6
# Comedy     7.901290  8.6  7.6
# Crime      8.016822  9.2  7.6
# Drama      7.957439  9.3  7.6
# Family     7.800000  7.8  7.8
# Fantasy    8.000000  8.1  7.9
# Film-Noir  7.966667  8.1  7.8
# Horror     7.909091  8.5  7.6
# Mystery    7.975000  8.4  7.6
# Thriller   7.800000  7.8  7.8
# Western    8.350000  8.8  7.8
