# %% [markdown]
# # Tasks for Data Visualization

# %% [markdown]
# ## 1. Load and Display Data → Read the dataset and print the first 5 rows

# %%
import pandas as pd

file = pd.read_csv('covid_19_country_wise_latest-Copy1.csv')

file.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# ## 2. Set the Dataset index is Unnamed: 0

# %%
file.set_index('Unnamed: 0',inplace = True)

# %%
file
# Out:
#                 Country/Region  Confirmed Deaths  Recovered  Active  \
# Unnamed: 0
# 0                  Afghanistan      36263   1269      25198    9796
# 1                      Albania       4880    144       2745    1991
# 2                      Algeria      27973   1163      18837    7973
# 3                      Andorra        907     52        803      52
# 4                       Angola        950     41        242     667
# ...                        ...        ...    ...        ...     ...
# 182         West Bank and Gaza      10621     78       3752    6791
# 183             Western Sahara         10      1          8       1
# 184                      Yemen       1691    483        833     375
# 185                     Zambia       4552    140       2815    1597
# 186                   Zimbabwe       2704    non        542    2126
#
#             New cases  New deaths  New recovered  Deaths / 100 Cases  \
# Unnamed: 0
# ...

# %% [markdown]
# ## 3. Now replace the index column Unnamed: 0 name with index

# %%
file.index.name = 'Index'

# %%
file
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %% [markdown]
# ## 4. Create Function that take dataset columns and replace whitespace
# ## with Underscore and update dataset automatically and the pass the
# ## dataset.

# %%
def replace_whitespace_with_underscore(file):
    file.columns = file.columns.str.replace(' ', '_')
    return file

# %%
replace_whitespace_with_underscore(file)
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# Index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %% [markdown]
# ## 5. Check Basic Information → Find column names, data types, and missing values.

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    object
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New_cases               177 non-null    float64
#  6   New_deaths              177 non-null    float64
#  7   New_recovered           187 non-null    int64
#  8   Deaths_/_100_Cases      187 non-null    float64
#  9   Recovered_/_100_Cases   187 non-null    float64
#  10  Deaths_/_100_Recovered  187 non-null    float64
#  11  Confirmed_last_week     187 non-null    int64
#  12  1_week_change           187 non-null    int64
#  13  1_week_%_increase       187 non-null    float64
# ...

# %% [markdown]
# ## Task 6: Fill NaN Values with the Mean of the Column

# %%
# Select the columns having the datatype float
numerical_cols = file.select_dtypes(include=['float64']).columns

# Fill that columns with there respective mean
file[numerical_cols] = file[numerical_cols].fillna(file[numerical_cols].mean())

# %%
file
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# Index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %% [markdown]
# ## 7. Count the number of unique countries in the dataset.

# %%
file['Country/Region'].nunique()
# Out:
# 187

# %% [markdown]
# ## Step 8: Check and Remove Duplicate Country Entries

# %%
duplicates = file['Country/Region'].duplicated().sum()
print(duplicates)

if duplicates > 0:
    file = file.drop_duplicates(subset=['Country/Region'])
# Out:
# 0

# %% [markdown]
# ## Step 9: Calculate Mean, Median, and Standard Deviation of Total Cases

# %%
mean_cases = file['Confirmed'].mean()
median_cases = file['Confirmed'].median()
std_cases = file['Confirmed'].std()
print(f"Mean Total Cases: {mean_cases}")
print(f"Median Total Cases: {median_cases}")
print(f"Standard Deviation of Total Cases: {std_cases}")
# Out:
# Mean Total Cases: 88130.935828877
# Median Total Cases: 5059.0
# Standard Deviation of Total Cases: 383318.66383061546

# %% [markdown]
# ## Step 10: Replace Strings in 'Deaths' Column with Mean

# %%
file['Deaths'] = pd.to_numeric(file['Deaths'], errors='coerce')

# Calculate mean and fill NaN
mean_deaths = file['Deaths'].mean()
file['Deaths'] = file['Deaths'].fillna(mean_deaths)

# %%
file.Deaths
# Out:
# Index
# 0      1269.000000
# 1       144.000000
# 2      1163.000000
# 3        52.000000
# 4        41.000000
#           ...
# 182      78.000000
# 183       1.000000
# 184     483.000000
# 185     140.000000
# 186    3516.129032
# Name: Deaths, Length: 187, dtype: float64

# %% [markdown]
# ## Step 11: Change Datatype of 'Deaths' Column

# %%
file['Deaths'] = file['Deaths'].astype(float)

# %%
file.Deaths.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 12: Calculate Total Deaths and Recoveries Worldwide

# %%
total_deaths = file['Deaths'].sum()
total_recoveries = file['Recovered'].sum()
print(f"Total Deaths Worldwide: {total_deaths}")
print(f"Total Recoveries Worldwide: {total_recoveries}")
# Out:
# Total Deaths Worldwide: 657516.1290322581
# Total Recoveries Worldwide: 9468087

# %% [markdown]
# ## Step 13: Count Countries with Over 1 Million Total Case

# %%
million_cases = (file['Confirmed'] > 1000000).sum()
print(f"Countries with >1M Total Cases: {million_cases}")
# Out:
# Countries with >1M Total Cases: 3

# %% [markdown]
# ## Step 14: Find Countries with Recovery Rate Above 95%

# %%
recovery_rate = file['Recovered'] / file['Confirmed']
high_recovery_countries = file[recovery_rate > 0.95]['Country/Region'].tolist()
print(f"Countries with >95% Recovery Rate: {high_recovery_countries}")
# Out:
# Countries with >95% Recovery Rate: ['Brunei', 'Djibouti', 'Dominica', 'Grenada', 'Holy See', 'Iceland', 'Malaysia', 'Mauritius', 'New Zealand', 'Norway', 'Qatar', 'Taiwan*']

# %% [markdown]
# ## Step 15: Drop 'WHO_Region' and 'Confirmed' Columns

# %%
file = file.drop(['WHO_Region', 'Confirmed'], axis=1)

# %% [markdown]
# ## Step 16: Find Country with Maximum Deaths

# %%
max_deaths_country = file.loc[file['Deaths'].idxmax(), 'Country/Region']
print(f"Country with Maximum Deaths: {max_deaths_country}")
# Out:
# Country with Maximum Deaths: US

# %% [markdown]
# ## Step 17: Sort Countries by Deaths in Descending Order

# %%
file = file.sort_values('Deaths', ascending=False)
print(file[['Country/Region', 'Deaths']].head())
# Out:
#        Country/Region    Deaths
# Index
# 173                US  148011.0
# 23             Brazil   87618.0
# 177    United Kingdom   45844.0
# 111            Mexico   44022.0
# 85              Italy   35112.0

# %% [markdown]
# ## Step 18: Create 'Total_Intellectuals' Column

# %%
file['Total_Intellectuals'] = file['Deaths'] + file['Recovered'] + file['Active']

# %%
file['Total_Intellectuals']
# Out:
# Index
# 173    4290259.0
# 23     2442375.0
# 177     301708.0
# 111     395489.0
# 85      246286.0
#          ...
# 19          99.0
# 130         62.0
# 75          12.0
# 30         226.0
# 114        289.0
# Name: Total_Intellectuals, Length: 187, dtype: float64

# %% [markdown]
# ## Step 19: Calculate Death Rate

# %%
file['Death_Rate'] = file['Deaths'] / file['Total_Intellectuals']

# %%
file['Death_Rate'].sum()
# Out:
# 6.201382129897446

# %% [markdown]
# ## Step 20: Identify Countries with Increasing Cases and Low Death Rates

# %%
increasing_low_death = file[(file['New_cases'] > 0) & (file['Death_Rate'] < 0.01)]['Country/Region'].tolist()
print(f"Countries with Increasing Cases and Low Death Rates: {increasing_low_death}")
# Out:
# Countries with Increasing Cases and Low Death Rates: ['Kazakhstan', 'Belarus', 'Israel', 'Kuwait', 'Oman', 'United Arab Emirates', 'Ghana', 'Qatar', 'Venezuela', 'Bahrain', 'Uzbekistan', 'Costa Rica', "Cote d'Ivoire", 'Madagascar', 'West Bank and Gaza', 'Tajikistan', 'Gabon', 'Nepal', 'Guinea', 'Paraguay', 'Singapore', 'Cabo Verde', 'Maldives', 'Sri Lanka', 'Jordan', 'Mozambique', 'Iceland', 'Namibia', 'Rwanda', 'Uganda', 'Botswana', 'Burundi', 'Vietnam', 'Eritrea', 'Greenland', 'Bhutan', 'Cambodia', 'Mongolia']

# %% [markdown]
# ## Step 21: Print Head of 'Country/Region' and 'Death_Rate'

# %%
file[['Death_Rate' ,'Country/Region']].head()
# Out:
#        Death_Rate  Country/Region
# Index
# 173      0.034499              US
# 23       0.035874          Brazil
# 177      0.151948  United Kingdom
# 111      0.111310          Mexico
# 85       0.142566           Italy

# %% [markdown]
# ## Step 22: Create a Scatter Plot of Total Cases vs. Total Deaths

# %%
import matplotlib.pyplot as plt

plt.scatter(file['Total_Intellectuals'], file['Deaths'])
plt.xlabel('Total Cases')
plt.ylabel('Total Deaths')
plt.title('Total Cases vs. Total Deaths')
plt.show()

# %% [markdown]
# ## Step 23: Save the Dataset to CSV

# %%
file.to_csv('modified_dataset.csv', index=True )

# %%
file
# Out:
#          Country/Region    Deaths  Recovered   Active     New_cases  \
# Index
# 173                  US  148011.0    1325804  2816444  56336.000000
# 23               Brazil   87618.0    1846641   508116  23284.000000
# 177      United Kingdom   45844.0       1437   254427    688.000000
# 111              Mexico   44022.0     303810    47657   4973.000000
# 85                Italy   35112.0     198593    12581    168.000000
# ...                 ...       ...        ...      ...           ...
# 19               Bhutan       0.0         86       13   1282.740113
# 130    Papua New Guinea       0.0         11       51      0.000000
# 75             Holy See       0.0         12        0      0.000000
# 30             Cambodia       0.0        147       79      1.000000
# 114            Mongolia       0.0        222       67      1.000000
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# Index
# ...
